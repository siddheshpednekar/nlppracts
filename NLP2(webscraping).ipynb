# %%
#PRACTICAL -2
#WEB SCRAPPING

# %%
import requests
from bs4 import BeautifulSoup
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk

# %%
page =requests.get("https://www.rjcollege.edu.in/about-us/")
soup =BeautifulSoup(page.content,'html.parser')
str3 =soup.find_all('p')[0].get_text()
sents=sent_tokenize(str3)
sents
# Out:
# ['On the auspicious day of Shri Krishna Janmashtami, 15th August 1938, the people of Ghatkopar and the surrounding suburbs witnessed the birth of Hindi Vidya Prachar Samiti, a brain child of a visionary Late Shri Nandkishore Singh Jairamji.',
#  'The Samiti was established with the objectives of catering to the educational needs of the Hindi speaking community.',
#  'It made a humble beginning by starting a primary school, which gradually expanded into a full-fledged secondary school.',
#  'The Hindi High School with its high academic standards has carved for itself a place not only among leading secondary schools in Mumbai but also educational institutions imparting instructions in Hindi throughout Maharashtra.',
#  'With its primary objectives achieved the Samiti decided to extend its frontiers and broaden its horizons.',
# ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
len(sents)
# Out:
# 16

# %%
#PHOTO GALLERY URL
page3 =requests.get("https://www.rjcollege.edu.in/gallery/")
soup3 =BeautifulSoup(page3.content,'html.parser')
imgs=[]
getimgs=soup3.select('img')
for img  in getimgs:
    src=img.get('https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg')
    alt=img.get("RJ COLLEGE")
    imgs.append('https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg')

for img in imgs:
    print(img)
# Out:
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# https://www.rjcollege.edu.in/wp-content/uploads/2022/03/SP1_8796.jpg
# ...

# %%
page1 =requests.get("https://www.timeanddate.com/weather/india/mumbai")
soup1 =BeautifulSoup(page.content,'html.parser')
Table1=soup1.find_all('table',id="wt-48")
Table1
# Out:
# []

# %%
xmlpg =requests.get("https://www.w3schools.com/xml/")
s=BeautifulSoup(xmlpg,'xml.parser')

# %%
fromtext=s.find('from')

# %%
#json

# %%
xx= requests.get('https://reqres.in/')
datastatus=xx.status_code
datajson=xx.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-127-b9f828dc562a> in <module>()
#       1 xx= requests.get('https://reqres.in/')
#       2 datastatus=xx.status_code
# ----> 3 datajson=xx.json()
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ...
