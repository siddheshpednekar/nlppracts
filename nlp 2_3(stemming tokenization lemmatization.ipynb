# %%
#POS TAGGING
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('punkt')
from nltk import pos_tag
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
text =nltk.word_tokenize("I am Student of Rj College")

# %%
nltk.pos_tag(text)
# Out:
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('Student', 'NN'),
#  ('of', 'IN'),
#  ('Rj', 'NNP'),
#  ('College', 'NNP')]

# %%
text2=nltk.sent_tokenize("I am student of rj college MSC DATA SCIENCE PART 2")

# %%
print(text2)
# Out:
# ['I am student of rj college MSC DATA SCIENCE PART 2']

# %%
#split function
text3=(" i am a student of rj college.").split()
print(text3)
# Out:
# ['i', 'am', 'a', 'student', 'of', 'rj', 'college.']

# %%
tokenTags=pos_tag(text3)

# %%
print(tokenTags)
# Out:
# [('i', 'NN'), ('am', 'VBP'), ('a', 'DT'), ('student', 'NN'), ('of', 'IN'), ('rj', 'NN'), ('college.', 'NN')]

# %%
#stemming process
from nltk.stem import PorterStemmer as ps

# %%
text4=("i am student of rj college").split()

# %%
print(text4)
# Out:
# ['i', 'am', 'student', 'of', 'rj', 'college']

# %%
for word_tokenize  in text4:
  rootWord=ps().stem(word_tokenize)
  print(rootWord)
# Out:
# i
# am
# student
# of
# rj
# colleg

# %%
text5=["Unexpected","disagreement","disagree","agreement","quirkiness","historical","canonical","happiness","unkind","dogs","expected"]
for word_tokenize in text5:
    stemPrint=ps().stem(word_tokenize)
    print(word_tokenize," -Stem-",stemPrint)
# Out:
# Unexpected  -Stem- unexpect
# disagreement  -Stem- disagr
# disagree  -Stem- disagre
# agreement  -Stem- agreement
# quirkiness  -Stem- quirki
# historical  -Stem- histor
# canonical  -Stem- canon
# happiness  -Stem- happi
# unkind  -Stem- unkind
# dogs  -Stem- dog
# expected  -Stem- expect

# %%
#LEMMATIZATION

# %%
nltk.download('wordnet')
import nltk
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
text5 = "I am Studying in part 2."
tokenization = nltk.word_tokenize(text5)
for w in tokenization:
  print("Lemma for {} is {}".format(w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Lemma for I is I
# Lemma for am is am
# Lemma for Studying is Studying
# Lemma for in is in
# Lemma for part is part
# Lemma for 2 is 2
# Lemma for . is .

# %%
text6=["Unexpected","disagreement","disagree","agreement","quirkiness","historical","canonical","happiness","unkind","dogs","expected"]
for word_tokenize in text5:
    stemPrint=ps().stem(word_tokenize)
    print(word_tokenize," -Stem-",stemPrint)
for w in tokenization:
  print("Lemma for {} is {}".format(w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# I  -Stem- i
#    -Stem-
# a  -Stem- a
# m  -Stem- m
#    -Stem-
# S  -Stem- s
# t  -Stem- t
# u  -Stem- u
# d  -Stem- d
# y  -Stem- y
# i  -Stem- i
# n  -Stem- n
# g  -Stem- g
#    -Stem-
# i  -Stem- i
# n  -Stem- n
#    -Stem-
# p  -Stem- p
# a  -Stem- a
# r  -Stem- r
# t  -Stem- t
#    -Stem-
# 2  -Stem- 2
# .  -Stem- .
# Lemma for I is I
# Lemma for am is am
# Lemma for Studying is Studying
# Lemma for in is in
# Lemma for part is part
# Lemma for 2 is 2
# Lemma for . is .

# %%
#stemming working check morpheme affix and then print prefix it only remove ly
#lemmiatization : it check spelling of word in the wordnet

# %%
#text normalization
#1.whitespace tokenizer
#2.treebank

# %%
#1.tokenizing words
Text8= "this  is my Teacher's Pen, isn't it?"                 #1.whitespace Tokenizer
tokenizer=nltk.tokenize.WhitespaceTokenizer()
tokenizer.tokenize(Text8)
# Out:
# ['this', 'is', 'my', "Teacher's", 'Pen,', "isn't", 'it?']

# %%
tokenizer=nltk.tokenize.TreebankWordDetokenizer()           #2.Treebank tokenizer
tokenizer.tokenize(Text8)
# Out:
# "t h i s     i s   m y   T e a c h e r' s   P e n,   i s n' t   i t?"

# %%
tokenizer=nltk.tokenize.WordPunctTokenizer()            #3 wordpunt tokenizer
tokenizer.tokenize(Text8)
# Out:
# ['this',
#  'is',
#  'my',
#  'Teacher',
#  "'",
#  's',
#  'Pen',
#  ',',
#  'isn',
#  "'",
#  't',
#  'it',
#  '?']

# %%
import re

# %%
#import the regular  expression library
#splits the word 'ARtificial Intelligence' by 'I'

text=re.split(r'i', 'Artificial Intelligence')
print(text)
# Out:
# ['Art', 'f', 'c', 'al Intell', 'gence']

# %%
from nltk import tokenize
text9="I am Student of MSc IT. I am Studying NLP course"
tokenizer=nltk.tokenize.WordPunctTokenizer()                      #regular expressions
tokenize=tokenizer.tokenize(text9)
wordlist = [w for w in tokenize if w.islower()]
wordlist
# Out:
# ['am', 'of', 'am', 'course']

# %%
te=[w for w in wordlist if re.search('rse',w)]          #identify the word rse in wordlist
te
# Out:
# ['course']

# %%
import re

result = re.match('Analytics',r'Analytics Vidhya is the largest data science community of India')
print(result)
# Out:
# <re.Match object; span=(0, 9), match='Analytics'>

# %%
# Regexptokenizer

from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer("[\w']+")
tokenizer.tokenize("Can't is a contraction.")
# Out:
# ["Can't", 'is', 'a', 'contraction']

# %%
#normalition the text of overheard.txt file of webtext corpus

# %%
import nltk
nltk.download("webtext")
from nltk.tokenize import PunktSentenceTokenizer
from nltk.corpus import webtext
# Out:
# [nltk_data] Downloading package webtext to /root/nltk_data...
# [nltk_data]   Package webtext is already up-to-date!

# %%
text10=webtext.raw('overheard.txt')
sent_tokenizer= PunktSentenceTokenizer(text10)
sents1=sent_tokenizer.tokenize(text10)

# %%
sents1
# Out:
# ['White guy: So, do you have any plans for this evening?',
#  'Asian girl: Yeah, being angry!',
#  'White guy: Oh, that sounds good.',
#  'Guy #1: So this Jack guy is basically the luckiest man in the world.',
#  "Guy #2: Why, because he's survived like 5 attempts on his life and it's not even noon?",
#  'Guy #1: No; he could totally nail those two chicks.',
#  'Dad: Could you tell me where the auditorium is?',
#  "Security guy: It's on the second floor.",
#  "Dad: Wait, you mean it's actually in the building?",
#  "Girl: But, I mean, it's not like I ever plan on giving birth.",
#  "Guy: Well, if your mother gave birth, it's like your chances are good that you'll give birth too.",
#  'Girl: ...Uh, dude, mother gave birth.',
#  'Guy: Absolutely.',
#  "Guy #1: I don't mind getting old; I love getting old.",
#  "Guy #2: Yeah, just as long as you don't get pregnant.",
#  'Hobo: Can you spare any change?',
#  'Man: Sorry, no.',
#  'Hobo: Who the hell you saying no to?',
# ...

# %%
for word_tokenize  in text10:
  rootWord=ps().stem(word_tokenize)
  print(rootWord)
# Out:
# Streaming output truncated to the last 5000 lines.
# o
# u
#
# d
# r
# i
# n
# k
# i
# n
# g
#
# t
# o
# n
# i
# g
# h
# t
# ?
#
#
# m
# e
# a
# t
# h
# e
# a
# d
#
# #
# 2
# :
#
# i
# t
# '
# s
#
# t
# u
# e
# s
# d
# a
# y
# .
# .
# .
#
# o
# f
#
# c
# o
# u
# r
# s
# e
#
# i
# '
# m
#
# d
# r
# i
# n
# k
# i
# n
# g
#
# t
# o
# n
# i
# g
# h
# t
# .
#
#
#
#
# b
# a
# r
# n
# a
# r
# d
#
# g
# i
# r
# l
#
# #
# 1
# :
#
# w
# a
# i
# t
# ,
#
# s
# o
#
# h
# e
#
# b
# r
# o
# k
# e
#
# u
# p
#
# w
# i
# t
# h
#
# y
# o
# u
# ?
#
# w
# h
# a
# t
#
# a
#
# j
# e
# r
# k
# !
#
#
# b
# a
# r
# n
# a
# r
# d
#
# g
# i
# r
# l
#
# #
# 2
# :
#
# i
#
# k
# n
# o
# w
# ,
#
# b
# u
# t
#
# w
# h
# a
# t
# e
# v
# e
# r
#
# -
# -
#
# i
# t
# '
# s
#
# h
# i
# s
#
# l
# o
# s
# s
# .
#
#
# b
# a
# r
# n
# a
# r
# d
#
# g
# i
# r
# l
#
# #
# 1
# :
#
# b
# u
# t
#
# d
# i
# d
#
# h
# e
#
# e
# v
# e
# n
#
# t
# e
# l
# l
#
# y
# o
# u
#
# w
# h
# y
# ?
#
# w
# h
# a
# t
#
# a
#
# p
# i
# e
# c
# ...

# %%
for word_tokenize in text10:
    stemPrint=ps().stem(word_tokenize)
    print(word_tokenize," -Stem-",stemPrint)
for w in tokenization:
  print("Lemma for {} is {}".format(w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# Streaming output truncated to the last 5000 lines.
# s  -Stem- s
# o  -Stem- o
#    -Stem-
# h  -Stem- h
# e  -Stem- e
#    -Stem-
# b  -Stem- b
# r  -Stem- r
# o  -Stem- o
# k  -Stem- k
# e  -Stem- e
#    -Stem-
# u  -Stem- u
# p  -Stem- p
#    -Stem-
# w  -Stem- w
# i  -Stem- i
# t  -Stem- t
# h  -Stem- h
#    -Stem-
# y  -Stem- y
# o  -Stem- o
# u  -Stem- u
# ?  -Stem- ?
#    -Stem-
# W  -Stem- w
# h  -Stem- h
# a  -Stem- a
# t  -Stem- t
#    -Stem-
# a  -Stem- a
#    -Stem-
# j  -Stem- j
# e  -Stem- e
# r  -Stem- r
# k  -Stem- k
# !  -Stem- !
#
#   -Stem-
#
# B  -Stem- b
# a  -Stem- a
# r  -Stem- r
# n  -Stem- n
# a  -Stem- a
# r  -Stem- r
# d  -Stem- d
#    -Stem-
# g  -Stem- g
# i  -Stem- i
# r  -Stem- r
# l  -Stem- l
#    -Stem-
# #  -Stem- #
# 2  -Stem- 2
# :  -Stem- :
#    -Stem-
# I  -Stem- i
#    -Stem-
# k  -Stem- k
# n  -Stem- n
# o  -Stem- o
# w  -Stem- w
# ,  -Stem- ,
#    -Stem-
# b  -Stem- b
# u  -Stem- u
# t  -Stem- t
#    -Stem-
# w  -Stem- w
# h  -Stem- h
# ...

# %%
import nltk
tokenizer=nltk.tokenize.WordPunctTokenizer()            #3 wordpunt tokenizer
tokenizer.tokenize(Text10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e2039bca0cba> in <module>()
#       1 import nltk
#       2 tokenizer=nltk.tokenize.WordPunctTokenizer()            #3 wordpunt tokenizer
# ----> 3 tokenizer.tokenize(Text10)
#
# NameError: name 'Text10' is not defined

# %%
import nltk
print(nltk.pos_tag(tex10))

# %%
from nltk.parse.api import ParserI
import nltk
from nltk.parse import RecursiveDescentParser
prod_rule=nltk.CFG.fromstring("""
S -> NP VP
NP -> N
NP -> Det N
VP -> V NP
VP -> V
N -> 'Person Name' | 'He'| 'She'| 'Boy' | 'Girl'| 'It'| 'cricket'| 'song' |'book'

V ->'likes' |'reads' | 'sings'  """)


sent='He likes cricket'

sent2=sent.split()
sent2
Parser = nltk.RecursiveDescentParser(prod_rule)
Parser

for t in  parser.parse(sent2):
  print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e19815f81197> in <module>()
#      20 Parser
#      21
# ---> 22 for t in  parser.parse(sent2):
#      23   print(t)
#
# NameError: name 'parser' is not defined

# %%
#find the pos tag of the following sentences and display the parse tree
#"i am a student of rj college i am studeying in msc dsai part-2  and msc Dsai is very good Course"
